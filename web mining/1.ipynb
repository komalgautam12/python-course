# %%
import requests

# %%
page=req
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File C:\ProgramData\Miniconda3\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/urllib3/connectionpool.py?line=701'>702</a> # Make the request on the httplib connection object.
# --> <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/urllib3/connectionpool.py?line=702'>703</a> httplib_response = self._make_request(
#     <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/urllib3/connectionpool.py?line=703'>704</a>     conn,
#     <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/urllib3/connectionpool.py?line=704'>705</a>     method,
# ...

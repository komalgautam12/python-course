# %%
import os

# %%
import PANDAS
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\samsa\OneDrive\Documents\GitHub\python-course\pre_defind_function.ipynb Cell 3' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/samsa/OneDrive/Documents/GitHub/python-course/pre_defind_function.ipynb#ch0000004?line=0'>1</a> import PANDAS
#
# ModuleNotFoundError: No module named 'PANDAS'

# %%
import pandas
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\samsa\OneDrive\Documents\GitHub\python-course\pre_defind_function.ipynb Cell 4' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/samsa/OneDrive/Documents/GitHub/python-course/pre_defind_function.ipynb#ch0000005?line=0'>1</a> import pandas
#
# ModuleNotFoundError: No module named 'pandas'

# %%
os.getcwd()# display the current working director
# Out:
# 'c:\\Users\\samsa\\OneDrive\\Documents\\GitHub\\python-course'

# %%
os.makedirs('codes')# create  a directory

# %%
if os.path.exists('codes'):
    print('the directory exists')
else:
    os.mkdir('codes')
# Out:
# the directory exists

# %%
os.listdir()
# Out:
# ['.git',
#  '.gitattributes',
#  'basic.ipynb',
#  'codes',
#  'condition.ipynb',
#  'dictionary.ipynb',
#  'emoji.ipynb',
#  'list.ipynb',
#  'list_advance.ipynb',
#  'loop.ipynb',
#  'pre_defind_function.ipynb',
#  'set.ipynb',
#  'string.ipynb',
#  'task.ipynb',
#  'tuple.ipynb']

# %%
os.listdir('c:/windows')
window_content=os.listdir('c:/windows')
print(f'{len(window_content)} item in the directory')
print(window_content)
# Out:
# 111 item in the directory
# ...

# %%
images=os.listdir('C:\\Users\\samsa\\OneDrive\\Pictures')
images
# Out:
# ['.tmp.drivedownload',
#  '31.png',
#  'ashu verma v2.png',
#  'ashu verma.png',
#  'ASSIGHMENT.png',
#  'assiognment ss',
#  'bank passbook.jpeg',
#  'BlueStacks',
#  'Camera Roll',
#  'caste.jpeg',
#  'chotu.png',
#  'chotu1.png',
#  'degree.jpeg',
#  'desktop.ini',
#  'file-20171025-25516-g7rtyl (2).jpg',
#  'file-20171025-25516-g7rtyl 1.jpg',
#  'file-20171025-25516-g7rtyl.jpg',
#  'gulab nandpal.png',
#  'Image (23).jpg',
#  'Image (24).jpg',
#  'Image (25).jpg',
#  'Image (26).jpg',
#  'Image (27).jpg',
#  'Image (30).jpg',
#  'Image (42).jpg',
#  'Image (43).jpg',
#  'image (44).png',
#  'IMG20211216142546.jpg',
#  'income.jpeg',
#  'InkedWhatsApp Image 2021-11-01 at 2.42.06 PM_LI.jpg',
#  'KOMAL.png',
#  'KOMAL1.png',
#  'malti adhaar.png',
#  'mark 10.jpeg',
#  'marksheet 10.png',
#  'mevalaal.png',
#  'n1.png',
#  'n2.png',
#  'n3.png',
#  'p1.png',
#  'p2.png',
#  'Padmavati.png',
#  'physics-tuition-500x500.jpg',
#  'pratima.png',
#  'rajjo part 2.png',
#  'rajjo.png',
# ...

# %%
os.path.isfile(images[0])
# Out:
# False

# %%
os.path.splitext(images[0])
# Out:
# ('.tmp', '.drivedownload')

# %%
png_images=[file for file in images if file .endswith('.png')]
print(png_images)
# Out:
# ['31.png', 'ashu verma v2.png', 'ashu verma.png', 'ASSIGHMENT.png', 'chotu.png', 'chotu1.png', 'gulab nandpal.png', 'image (44).png', 'KOMAL.png', 'KOMAL1.png', 'malti adhaar.png', 'marksheet 10.png', 'mevalaal.png', 'n1.png', 'n2.png', 'n3.png', 'p1.png', 'p2.png', 'Padmavati.png', 'pratima.png', 'rajjo part 2.png', 'rajjo.png', 'Ram Gopal.png', 'S1.png', 'Screenshot 2021-08-09 172815.png', 'Screenshot 2021-08-09 175016.png', 'Screenshot 2021-08-09 175901.png', 'Screenshot 2021-08-09 180307.png', 'Screenshot 2021-08-09 180356.png', 'Screenshot 2021-08-09 181358.png', 'Screenshot 2021-08-09 182404.png', 'Screenshot 2021-08-09 182904.png', 'Screenshot 2021-08-09 183232.png', 'Screenshot 2021-10-27 212333.png', 'Screenshot 2021-11-11 160835.png', 'Screenshot_2022-01-03-22-18-27-65.png', 'Screenshot_2022-01-03-22-18-35-48.png', 'Shyamkali urf Shyamwati.png', 'valo 7 compi.png']

# %%
import requests

# %%
page=requests.get('https://en.wikipedia.org/wiki/Main_Page')
page
# Out:
# <Response [200]>

# %%
page.text
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Wikipedia, the free encyclopedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"dc0486f6-6770-434e-8603-90d608dbeba3","wgCSPNonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Main_Page","wgTitle":"Main Page","wgCurRevisionId":1069328725,"wgRevisionId":1069328725,"wgArticleId":15580374,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":[],"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"Main_Page","wgRelevantArticleId":15580374,"wgIsProbablyEditab
# ...

# %%
import random
